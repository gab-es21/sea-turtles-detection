# %% [markdown]
# <a href="https://colab.research.google.com/github/gab-es21/sea-turtles-detection/blob/main/yolov8/01_yolo_v8_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sea Turtle Detection - Yolov8 Train

# %% [markdown]
# ## Imports and GPU Check

# %% [markdown]
# Check access to GPU.

# %%
# !pip install nvidia-cuda-runtime-cu12
# !pip install cuda-python

# !pip install torch==2.1.0+cu121 torchvision==0.16.0+cu121 -f https://download.pytorch.org/whl/torch_stable.html

# !pip install roboflow
# !pip install -U ultralytics

# !pip install python-dotenv
# !pip install pickleshare

# !nvidia-smi
# Out:
# Requirement already satisfied: nvidia-cuda-runtime-cu12 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (12.3.52)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: cuda-python in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (12.3.0)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==2.1.0+cu121 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (2.1.0+cu121)
# Requirement already satisfied: torchvision==0.16.0+cu121 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (0.16.0+cu121)
# Requirement already satisfied: filelock in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch==2.1.0+cu121) (3.13.1)
# Requirement already satisfied: typing-extensions in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch==2.1.0+cu121) (4.8.0)
# Requirement already satisfied: sympy in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch==2.1.0+cu121) (1.12)
# Requirement already satisfied: networkx in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch==2.1.0+cu121) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch==2.1.0+cu121) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch==2.1.0+cu121) (2023.10.0)
# Requirement already satisfied: numpy in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torchvision==0.16.0+cu121) (1.26.1)
# Requirement already satisfied: requests in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torchvision==0.16.0+cu121) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torchvision==0.16.0+cu121) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from jinja2->torch==2.1.0+cu121) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from requests->torchvision==0.16.0+cu121) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from requests->torchvision==0.16.0+cu121) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from requests->torchvision==0.16.0+cu121) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from requests->torchvision==0.16.0+cu121) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from sympy->torch==2.1.0+cu121) (1.3.0)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: roboflow in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (1.1.9)
# Requirement already satisfied: certifi==2023.7.22 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (3.8.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (1.26.1)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (10.1.0)
# Requirement already satisfied: pyparsing==2.4.7 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (2.4.7)
# Requirement already satisfied: python-dateutil in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: supervision in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (0.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from roboflow) (0.4.27)
# Requirement already satisfied: colorama in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from matplotlib->roboflow) (4.44.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from supervision->roboflow) (1.11.3)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ultralytics in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (8.0.196)
# Collecting ultralytics
#   Using cached ultralytics-8.1.8-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (3.8.1)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (1.26.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (4.8.1.78)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (10.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (1.11.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (5.9.6)
# Requirement already satisfied: py-cpuinfo in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from ultralytics) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.8.0)
# Requirement already satisfied: sympy in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.10.0)
# Requirement already satisfied: colorama in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Using cached ultralytics-8.1.8-py3-none-any.whl (709 kB)
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.196
#     Uninstalling ultralytics-8.0.196:
#       Successfully uninstalled ultralytics-8.0.196
# Successfully installed ultralytics-8.1.8
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (1.0.0)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pickleshare in c:\users\gaby3\documents\sea-turtles-detection\.venv\lib\site-packages (0.7.5)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Thu Feb  1 01:16:25 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.84                 Driver Version: 545.84       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3070      WDDM  | 00000000:2B:00.0  On |                  N/A |
# |  0%   51C    P8              28W / 240W |   1091MiB /  8192MiB |     23%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      3624    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A      6132    C+G   ...inaries\Win64\EpicGamesLauncher.exe    N/A      |
# |    0   N/A  N/A      6240    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A      6340    C+G   ...oogle\Chrome\Application\chrome.exe    N/A      |
# |    0   N/A  N/A      8108    C+G   ...2txyewy\StartMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A      8904    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     11224    C+G   ...ne\Binaries\Win64\EpicWebHelper.exe    N/A      |
# |    0   N/A  N/A     13024    C+G   ...GeForce Experience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     13168    C+G   ...GeForce Experience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     13204    C+G   ...5n1h2txyewy\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     14096    C+G   ....0_x64__kzh8wxbdkxb8p\DCv2\DCv2.exe    N/A      |
# |    0   N/A  N/A     14576    C+G   ...Programs\Microsoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A     16144    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A     17416    C+G   ...al\Discord\app-1.0.9031\Discord.exe    N/A      |
# |    0   N/A  N/A     19400    C+G   ...wekyb3d8bbwe\XboxGameBarWidgets.exe    N/A      |
# |    0   N/A  N/A     20092    C+G   ...siveControlPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     20220    C+G   ...al\Discord\app-1.0.9031\Discord.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %%
import os
import dotenv

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local

# %% [markdown]
# ## Get Environment Variables from drive

# %% [markdown]
# Load the .env file

# %%
dotenv.load_dotenv('../yolov8_local/yolov8.env')
# Out:
# True

# %%
ROBOFLOW_API_KEY = os.environ.get('ROBOFLOW_API_KEY')

ROBOFLOW_WORKSPACE = os.environ.get('ROBOFLOW_WORKSPACE')
ROBOFLOW_PROJECT = os.environ.get('ROBOFLOW_PROJECT')

ROBOFLOW_MODEL = os.environ.get('ROBOFLOW_MODEL')
ROBOFLOW_VERSION = os.environ.get('ROBOFLOW_VERSION')

# %% [markdown]
# ## Install YOLOv8
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO
from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.11.7 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# Setup complete ✅ (12 CPUs, 31.9 GB RAM, 634.2/1862.2 GB disk)

# %% [markdown]
# ## Model

# %%
from roboflow import Roboflow
rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace(ROBOFLOW_WORKSPACE).project(ROBOFLOW_PROJECT)
dataset = project.version(ROBOFLOW_VERSION).download(ROBOFLOW_MODEL)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.8, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in sea-turtles-1 to yolov8:: 100%|██████████| 90278/90278 [00:03<00:00, 23801.58it/s]
# Extracting Dataset Version Zip to sea-turtles-1 in yolov8:: 100%|██████████| 2728/2728 [00:00<00:00, 3017.13it/s]

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Custom Training
#
# The purpose of this code block is to train the YOLO v8 object detection model using the specified dataset.
#
#
# The model will be trained for 150 epochs, with images resized to 800x800 pixels during training.
#
#
# The loss curves will be plotted for visualization during the training process.

# %%
#model = YOLO(f'{HOME}/models/yolov8n.pt')
#model = YOLO(f'{HOME}/models/yolov8s.pt')
model = YOLO(f'{HOME}/models/yolov8m.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8m.pt to 'c:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local\models\yolov8m.pt'...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 75.8MB/s]

# %%
print(dataset.location)
print(HOME)
# Out:
# c:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local\sea-turtles-1
# c:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.version.cuda)
# Out:
# True
# 1
# 12.1

# %%
# !yolo checks
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.11.7 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# Setup complete ✅ (12 CPUs, 31.9 GB RAM, 634.3/1862.2 GB disk)
#
# OS                  Windows-10-10.0.22631-SP0
# Environment         Windows
# Python              3.11.7
# Install             git
# RAM                 31.93 GB
# CPU                 AMD Ryzen 5 5600X 6-Core Processor
# CUDA                12.1
#
# matplotlib          ✅ 3.8.1>=3.3.0
# numpy               ✅ 1.26.1>=1.22.2
# opencv-python       ✅ 4.8.1.78>=4.6.0
# pillow              ✅ 10.1.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.3>=1.4.1
# torch               ✅ 2.1.0+cu121>=1.8.0
# torchvision         ✅ 0.16.0+cu121>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# psutil              ✅ 5.9.6
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1
# pandas              ✅ 2.1.2>=1.1.4
# seaborn             ✅ 0.13.0>=0.11.0

# %% [markdown]
# Go to sea-turtles-1/data.yaml, and update the last 2 lines to:
#
# ```yaml
# train: ../train/images
# val: ../valid/images
# ```

# %%
# !yolo cfg={HOME}/cfg/cfg_medium_train.yaml
# Out:
# ^C

# %%
#!yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=400 imgsz=800 plots=True device=0 patience=50 verbose=True
# Out:
# Ultralytics YOLOv8.0.209  Python-3.11.6 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=c:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local\sea-turtles-1/data.yaml, epochs=400, patience=50, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=0, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=c:\Users\gaby3\Documents\sea-turtles-detection\runs\detect\train
# Traceback (most recent call last):
#   File "c:\Users\gaby3\Documents\sea-turtles-detection\.venv\Lib\site-packages\ultralytics\engine\trainer.py", line 116, in __init__
#     self.data = check_det_dataset(self.args.data)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gaby3\Documents\sea-turtles-detection\.venv\Lib\site-packages\ultralytics\data\utils.py", line 313, in check_det_dataset
#     raise FileNotFoundError(m)
# FileNotFoundError:
# Dataset 'c://Users/gaby3/Documents/sea-turtles-detection/yolov8_local/sea-turtles-1/data.yaml' images not found ⚠️, missing path 'C:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local\sea-turtles-1\sea-turtles-1\valid\images'
# Note dataset download directory is 'C:\Users\gaby3\Documents\datasets'. You can update this in 'C:\Users\gaby3\AppData\Roaming\Ultralytics\settings.yaml'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\gaby3\Documents\sea-turtles-detection\.venv\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "c:\Users\gaby3\Documents\sea-turtles-detection\.venv\Lib\site-packages\ultralytics\cfg\__init__.py", line 445, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gaby3\Documents\sea-turtles-detection\.venv\Lib\site-packages\ultralytics\engine\model.py", line 333, in train
#     self.trainer = (trainer or self._smart_load('trainer'))(overrides=args, _callbacks=self.callbacks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gaby3\Documents\sea-turtles-detection\.venv\Lib\site-packages\ultralytics\engine\trainer.py", line 120, in __init__
#     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
# RuntimeError: Dataset 'c://Users/gaby3/Documents/sea-turtles-detection/yolov8_local/sea-turtles-1/data.yaml' error
# Dataset 'c://Users/gaby3/Documents/sea-turtles-detection/yolov8_local/sea-turtles-1/data.yaml' images not found , missing path 'C:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local\sea-turtles-1\sea-turtles-1\valid\images'
# Note dataset download directory is 'C:\Users\gaby3\Documents\datasets'. You can update this in 'C:\Users\gaby3\AppData\Roaming\Ultralytics\settings.yaml'

# %%
print(HOME)
# Out:
# c:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local

# %%
# %cd {HOME}
Image(filename=f'./runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# c:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local

# %%
# %cd {HOME}
Image(filename=f'./runs/detect/train2/results.png', width=600)
# Out:
# c:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local

# %%
# %cd {HOME}
Image(filename=f'./runs/detect/train2/val_batch0_pred.jpg', width=600)
# Out:
# c:\Users\gaby3\Documents\sea-turtles-detection\yolov8_local
